# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns
import lightgbm as lgb
import warnings

warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
pd.set_option('display.width', 500)
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# Reading the data

# %%
train = pd.read_csv('train 2.csv', parse_dates=['date'])
test = pd.read_csv('test.csv', parse_dates=['date'])

df = pd.concat([train, test], sort=False)

# %% [markdown]
# Data Analysis

# %%
df.shape
# Out:
# (958000, 5)

# %%
df.head()
# Out:
#         date  store  item  sales  id
# 0 2013-01-01      1     1   13.0 NaN
# 1 2013-01-02      1     1   11.0 NaN
# 2 2013-01-03      1     1   14.0 NaN
# 3 2013-01-04      1     1   13.0 NaN
# 4 2013-01-05      1     1   10.0 NaN

# %%
df.tail()
# Out:
#             date  store  item  sales       id
# 44995 2018-03-27     10    50    NaN  44995.0
# 44996 2018-03-28     10    50    NaN  44996.0
# 44997 2018-03-29     10    50    NaN  44997.0
# 44998 2018-03-30     10    50    NaN  44998.0
# 44999 2018-03-31     10    50    NaN  44999.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 958000 entries, 0 to 44999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    958000 non-null  datetime64[ns]
#  1   store   958000 non-null  int64
#  2   item    958000 non-null  int64
#  3   sales   913000 non-null  float64
#  4   id      45000 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 43.9 MB

# %%
df.describe().T
# Out:
#           count                           mean                  min                  25%                  50%                  75%                  max           std
# date     958000  2015-08-16 11:59:59.999999744  2013-01-01 00:00:00  2014-04-24 18:00:00  2015-08-16 12:00:00  2016-12-07 06:00:00  2018-03-31 00:00:00           NaN
# store  958000.0                            5.5                  1.0                  3.0                  5.5                  8.0                 10.0      2.872283
# item   958000.0                           25.5                  1.0                 13.0                 25.5                 38.0                 50.0     14.430877
# sales  913000.0                      52.250287                  0.0                 30.0                 47.0                 70.0                231.0     28.801144
# id      45000.0                        22499.5                  0.0             11249.75              22499.5             33749.25              44999.0  12990.525394

# %%
df.isnull().sum()
# Out:
# date          0
# store         0
# item          0
# sales     45000
# id       913000
# dtype: int64

# %%
df["date"].min(), df["date"].max()
# Out:
# (Timestamp('2013-01-01 00:00:00'), Timestamp('2018-03-31 00:00:00'))

# %%
df.groupby(["store", "item"]).agg({"sales": ["sum", "mean", "median", "std", "count"]})
# Out:
#                sales
#                  sum       mean median        std count
# store item
# 1     1      36468.0  19.971522   19.0   6.741022  1826
#       2      97050.0  53.148959   52.0  15.005779  1826
#       3      60638.0  33.208105   33.0  10.072529  1826
#       4      36440.0  19.956188   20.0   6.640618  1826
#       5      30335.0  16.612815   16.0   5.672102  1826
# ...              ...        ...    ...        ...   ...
# 10    46    120601.0  66.046550   65.0  18.114991  1826
#       47     45204.0  24.755750   24.0   7.924820  1826
#       48    105570.0  57.814896   57.0  15.898538  1826
#       49     60317.0  33.032311   32.0  10.091610  1826
#       50    135192.0  74.037240   73.0  19.937566  1826
#
# [500 rows x 5 columns]

# %%
df[["sales"]].plot()
plt.show(block=True)

# %% [markdown]
# Time Series usually consist of three components:
#
# * *trend* component
# * *seasonality* component
# * *residual* (*noise*) component
#
# Here we can see mostly seasonality component

# %% [markdown]
# Feature Engineering

# %%
df['year'] = df.date.dt.year
df['month'] = df.date.dt.month
df['quarter_of_year'] = df.date.dt.quarter
df['week_of_year'] = df.date.dt.isocalendar().week
df['day_of_year'] = df.date.dt.dayofyear
df['day_of_month'] = df.date.dt.day
df['day_of_week'] = df.date.dt.dayofweek
df["is_wknd"] = df.date.dt.weekday // 5
df['is_month_start'] = df.date.dt.is_month_start.astype(int)
df['is_month_end'] = df.date.dt.is_month_end.astype(int)

# %% [markdown]
# Lag/Shifted Features

# %%
df.sort_values(by=['store', 'item', 'date'], axis=0, inplace=True)

# %%
pd.DataFrame({"sales": df["sales"].values[0:10],
              "lag1": df["sales"].shift(1).values[0:10],
              "lag2": df["sales"].shift(2).values[0:10],
              "lag3": df["sales"].shift(3).values[0:10],
              "lag4": df["sales"].shift(4).values[0:10]})
# Out:
#    sales  lag1  lag2  lag3  lag4
# 0   13.0   NaN   NaN   NaN   NaN
# 1   11.0  13.0   NaN   NaN   NaN
# 2   14.0  11.0  13.0   NaN   NaN
# 3   13.0  14.0  11.0  13.0   NaN
# 4   10.0  13.0  14.0  11.0  13.0
# 5   12.0  10.0  13.0  14.0  11.0
# 6   10.0  12.0  10.0  13.0  14.0
# 7    9.0  10.0  12.0  10.0  13.0
# 8   12.0   9.0  10.0  12.0  10.0
# 9    9.0  12.0   9.0  10.0  12.0

# %%
df.groupby(["store", "item"])['sales'].head()
# Out:
# 0         13.0
# 1         11.0
# 2         14.0
# 3         13.0
# 4         10.0
#           ...
# 911174    33.0
# 911175    37.0
# 911176    46.0
# 911177    51.0
# 911178    41.0
# Name: sales, Length: 2500, dtype: float64

# %%
df.groupby(["store", "item"])['sales'].transform(lambda x: x.shift(1))
# Out:
# 0         NaN
# 1        13.0
# 2        11.0
# 3        14.0
# 4        13.0
#          ...
# 44995     NaN
# 44996     NaN
# 44997     NaN
# 44998     NaN
# 44999     NaN
# Name: sales, Length: 958000, dtype: float64

# %%
def lag_features(dataframe, lags):
    for lag in lags:
        dataframe['sales_lag_' + str(lag)] = dataframe.groupby(["store", "item"])['sales'].transform(
            lambda x: x.shift(lag))
    return dataframe

# %%
df = lag_features(df, [1, 7, 14, 30, 90, 180, 365, 546, 730])

# %% [markdown]
# Rolling Mean Features

# %%
pd.DataFrame({"sales": df["sales"].values[0:10],
              "roll2": df["sales"].shift(1).rolling(window=2).mean().values[0:10],
              "roll3": df["sales"].shift(1).rolling(window=3).mean().values[0:10],
              "roll5": df["sales"].shift(1).rolling(window=5).mean().values[0:10]})
# Out:
#    sales  roll2      roll3  roll5
# 0   13.0    NaN        NaN    NaN
# 1   11.0    NaN        NaN    NaN
# 2   14.0   12.0        NaN    NaN
# 3   13.0   12.5  12.666667    NaN
# 4   10.0   13.5  12.666667    NaN
# 5   12.0   11.5  12.333333   12.2
# 6   10.0   11.0  11.666667   12.0
# 7    9.0   11.0  10.666667   11.8
# 8   12.0    9.5  10.333333   10.8
# 9    9.0   10.5  10.333333   10.6

# %%
def roll_mean_features(dataframe, windows):
    for window in windows:
        dataframe['sales_roll_mean_' + str(window)] = dataframe.groupby(["store", "item"])['sales']. \
                                                          transform(
            lambda x: x.shift(1).rolling(window=window, min_periods=10, win_type="triang").mean())
    return dataframe

# %%
df = roll_mean_features(df, [30, 365, 546])

# %% [markdown]
# Exponentially Weighted Mean Features
# $$
# y_0 = x_0
# $$
# $$
# y_t = (1-\alpha)y_{t-1} + \alpha x_t
# $$

# %%
pd.DataFrame({"sales": df["sales"].values[0:10],
              "roll2": df["sales"].shift(1).rolling(window=2).mean().values[0:10],
              "ewm099": df["sales"].shift(1).ewm(alpha=0.99).mean().values[0:10],
              "ewm095": df["sales"].shift(1).ewm(alpha=0.95).mean().values[0:10],
              "ewm07": df["sales"].shift(1).ewm(alpha=0.7).mean().values[0:10],
              "ewm02": df["sales"].shift(1).ewm(alpha=0.1).mean().values[0:10]})
# Out:
#    sales  roll2     ewm099     ewm095      ewm07      ewm02
# 0   13.0    NaN        NaN        NaN        NaN        NaN
# 1   11.0    NaN  13.000000  13.000000  13.000000  13.000000
# 2   14.0   12.0  11.019802  11.095238  11.461538  11.947368
# 3   13.0   12.5  13.970201  13.855107  13.287770  12.704797
# 4   10.0   13.5  13.009702  13.042750  13.084686  12.790637
# 5   12.0   11.5  10.030097  10.152137  10.920146  12.109179
# 6   10.0   11.0  11.980301  11.907607  11.676595  12.085878
# 7    9.0   11.0  10.019803  10.095380  10.502722  11.686057
# 8   12.0    9.5   9.010198   9.054769   9.450748  11.214433
# 9    9.0   10.5  11.970102  11.852738  11.235259  11.342672

# %%
def ewm_features(dataframe, alphas, lags):
    for alpha in alphas:
        for lag in lags:
            dataframe['sales_ewm_alpha_' + str(alpha).replace(".", "") + "_lag_" + str(lag)] = \
                dataframe.groupby(["store", "item"])['sales'].transform(lambda x: x.shift(lag).ewm(alpha=alpha).mean())
    return dataframe

# %%
alphas = [0.95, 0.9, 0.8, 0.7, 0.5]
lags = [90, 180, 270, 365, 546, 728]

# %%
df = ewm_features(df, alphas, lags)

# %%
sample_df = df[(df['store'] == 1) & (df['item'] == 1)].sort_values('date')
sample_df["sales"].reset_index(drop=True).plot(label='sales', color='green')
sample_df["sales_lag_30"].reset_index(drop=True).plot(label='lag 30', linestyle='--', linewidth=0.35, color='purple')
sample_df["sales_roll_mean_30"].reset_index(drop=True).plot(label='rolling mean 30', linewidth=2.5, color='red')
sample_df["sales_ewm_alpha_07_lag_180"].reset_index(drop=True).plot(label='ewm,alpha=0.7,lag=180', linestyle=':', color='skyblue')
plt.legend(ncol=2);

# %% [markdown]
# One-Hot Encoding

# %%
df = pd.get_dummies(df, columns=['store', 'item', 'day_of_week', 'month'])

# %% [markdown]
# Model

# %% [markdown]
# ### Symmetric MAPE (SMAPE)
# $$
# MAPE(y, \hat{y}) = \frac{1}{N}\sum_{i=1}^N |\frac{\hat{y}-y}{y}|\cdot 100\%
# $$
# $$
# SMAPE(y, \hat{y}) = \frac{1}{N}\sum_{i=1}^N \frac{|\hat{y}-y|}{\frac{1}{2}|y| + \frac{1}{2}|\hat{y}|}\cdot 100\%
# $$

# %%
def smape(preds, target):
    n = len(preds)
    masked_arr = ~((preds == 0) & (target == 0))
    preds, target = preds[masked_arr], target[masked_arr]
    num = np.abs(preds - target)
    denom = np.abs(preds) + np.abs(target)
    smape_val = (200 * np.sum(num / denom)) / n
    return smape_val


def lgbm_smape(preds, train_data):
    labels = train_data.get_label()
    smape_val = smape(preds, labels)
    return 'SMAPE', smape_val, False

# %%
train = df.loc[(df["date"] < "2017-01-01"), :]

val = df.loc[(df["date"] >= "2017-01-01") & (df["date"] < "2017-04-01"), :]

cols = [col for col in train.columns if col not in ['date', 'id', "sales", "year"]]

Y_train = train['sales']
X_train = train[cols]

Y_val = val['sales']
X_val = val[cols]

Y_train.shape, X_train.shape, Y_val.shape, X_val.shape
# Out:
# ((730500,), (730500, 128), (45000,), (45000, 128))

# %% [markdown]
# Time Series Model with LightGBM

# %%
lgb_params = {'num_leaves': 10,
              'learning_rate': 0.02,
              'feature_fraction': 0.8,
              'max_depth': 5,
              'verbose': 0,
              'num_boost_round': 10000,
              'nthread': -1}

# %%
lgbtrain = lgb.Dataset(data=X_train, label=Y_train, feature_name=cols)

lgbval = lgb.Dataset(data=X_val, label=Y_val, reference=lgbtrain, feature_name=cols)

# %%
model = lgb.train(lgb_params, lgbtrain,
                  valid_sets=[lgbtrain, lgbval],
                  num_boost_round=lgb_params['num_boost_round'],
                  feval=lgbm_smape,
                  callbacks=[lgb.early_stopping(stopping_rounds=200), lgb.log_evaluation(100)])
# Out:
# Training until validation scores don't improve for 200 rounds
# [100]	training's l2: 88.6847	training's SMAPE: 17.3501	valid_1's l2: 73.7789	valid_1's SMAPE: 17.6715
# [200]	training's l2: 64.4648	training's SMAPE: 14.3601	valid_1's l2: 58.3648	valid_1's SMAPE: 14.9466
# [300]	training's l2: 60.7413	training's SMAPE: 13.8311	valid_1's l2: 55.2978	valid_1's SMAPE: 14.4034
# [400]	training's l2: 59.1237	training's SMAPE: 13.6398	valid_1's l2: 53.8619	valid_1's SMAPE: 14.198
# [500]	training's l2: 58.1182	training's SMAPE: 13.5298	valid_1's l2: 52.9839	valid_1's SMAPE: 14.0915
# [600]	training's l2: 57.3872	training's SMAPE: 13.4563	valid_1's l2: 52.4115	valid_1's SMAPE: 14.0263
# [700]	training's l2: 56.8104	training's SMAPE: 13.4007	valid_1's l2: 51.9331	valid_1's SMAPE: 13.9735
# [800]	training's l2: 56.3386	training's SMAPE: 13.3531	valid_1's l2: 51.457	valid_1's SMAPE: 13.9222
# [900]	training's l2: 55.9242	training's SMAPE: 13.3112	valid_1's l2: 50.999	valid_1's SMAPE: 13.8737
# [1000]	training's l2: 55.5628	training's SMAPE: 13.2742	valid_1's l2: 50.6667	valid_1's SMAPE: 13.836
# [1100]	training's l2: 55.2461	training's SMAPE: 13.241	valid_1's l2: 50.3904	valid_1's SMAPE: 13.8042
# [1200]	training's l2: 54.9578	training's SMAPE: 13.2111	valid_1's l2: 50.1702	valid_1's SMAPE: 13.7804
# [1300]	training's l2: 54.6998	training's SMAPE: 13.1843	valid_1's l2: 49.9782	valid_1's SMAPE: 13.757
# [1400]	training's l2: 54.4572	training's SMAPE: 13.1599	valid_1's l2: 49.8179	valid_1's SMAPE: 13.7377
# [1500]	training's l2: 54.2447	training's SMAPE: 13.1366	valid_1's l2: 49.6579	valid_1's SMAPE: 13.7153
# [1600]	training's l2: 54.0479	training's SMAPE: 13.1166	valid_1's l2: 49.4999	valid_1's SMAPE: 13.6973
# [1700]	training's l2: 53.8695	training's SMAPE: 13.0974	valid_1's l2: 49.3655	valid_1's SMAPE: 13.6815
# [1800]	training's l2: 53.7066	training's SMAPE: 13.0811	valid_1's l2: 49.2365	valid_1's SMAPE: 13.6651
# [1900]	training's l2: 53.5581	training's SMAPE: 13.0666	valid_1's l2: 49.1259	valid_1's SMAPE: 13.6522
# [2000]	training's l2: 53.42	training's SMAPE: 13.0526	valid_1's l2: 49.0431	valid_1's SMAPE: 13.6409
# [2100]	training's l2: 53.2925	training's SMAPE: 13.0382	valid_1's l2: 48.9374	valid_1's SMAPE: 13.628
# [2200]	training's l2: 53.176	training's SMAPE: 13.0274	valid_1's l2: 48.8521	valid_1's SMAPE: 13.6179
# [2300]	training's l2: 53.066	training's SMAPE: 13.0165	valid_1's l2: 48.7807	valid_1's SMAPE: 13.6081
# [2400]	training's l2: 52.964	training's SMAPE: 13.0063	valid_1's l2: 48.7016	valid_1's SMAPE: 13.5997
# [2500]	training's l2: 52.8679	training's SMAPE: 12.9973	valid_1's l2: 48.6361	valid_1's SMAPE: 13.5922
# [2600]	training's l2: 52.7759	training's SMAPE: 12.9885	valid_1's l2: 48.582	valid_1's SMAPE: 13.5848
# [2700]	training's l2: 52.6892	training's SMAPE: 12.9798	valid_1's l2: 48.5082	valid_1's SMAPE: 13.5755
# [2800]	training's l2: 52.6064	training's SMAPE: 12.9715	valid_1's l2: 48.4493	valid_1's SMAPE: 13.5689
# [2900]	training's l2: 52.5286	training's SMAPE: 12.9638	valid_1's l2: 48.4098	valid_1's SMAPE: 13.5629
# [3000]	training's l2: 52.4544	training's SMAPE: 12.9564	valid_1's l2: 48.3617	valid_1's SMAPE: 13.5565
# [3100]	training's l2: 52.3848	training's SMAPE: 12.9498	valid_1's l2: 48.3197	valid_1's SMAPE: 13.5513
# [3200]	training's l2: 52.3177	training's SMAPE: 12.9432	valid_1's l2: 48.27	valid_1's SMAPE: 13.5452
# [3300]	training's l2: 52.2536	training's SMAPE: 12.937	valid_1's l2: 48.2266	valid_1's SMAPE: 13.54
# [3400]	training's l2: 52.1926	training's SMAPE: 12.931	valid_1's l2: 48.1951	valid_1's SMAPE: 13.5351
# [3500]	training's l2: 52.1343	training's SMAPE: 12.9253	valid_1's l2: 48.1605	valid_1's SMAPE: 13.5303
# [3600]	training's l2: 52.0774	training's SMAPE: 12.9198	valid_1's l2: 48.1279	valid_1's SMAPE: 13.5256
# [3700]	training's l2: 52.0221	training's SMAPE: 12.9148	valid_1's l2: 48.094	valid_1's SMAPE: 13.5217
# [3800]	training's l2: 51.9694	training's SMAPE: 12.9103	valid_1's l2: 48.0664	valid_1's SMAPE: 13.518
# [3900]	training's l2: 51.9195	training's SMAPE: 12.9056	valid_1's l2: 48.0381	valid_1's SMAPE: 13.5142
# [4000]	training's l2: 51.871	training's SMAPE: 12.9013	valid_1's l2: 48.0176	valid_1's SMAPE: 13.5116
# [4100]	training's l2: 51.8229	training's SMAPE: 12.897	valid_1's l2: 47.9973	valid_1's SMAPE: 13.5092
# [4200]	training's l2: 51.7759	training's SMAPE: 12.8932	valid_1's l2: 47.9704	valid_1's SMAPE: 13.506
# [4300]	training's l2: 51.7313	training's SMAPE: 12.889	valid_1's l2: 47.949	valid_1's SMAPE: 13.5036
# [4400]	training's l2: 51.6877	training's SMAPE: 12.8852	valid_1's l2: 47.9309	valid_1's SMAPE: 13.5012
# [4500]	training's l2: 51.6447	training's SMAPE: 12.8814	valid_1's l2: 47.9142	valid_1's SMAPE: 13.4992
# [4600]	training's l2: 51.6037	training's SMAPE: 12.8781	valid_1's l2: 47.8942	valid_1's SMAPE: 13.4967
# [4700]	training's l2: 51.5623	training's SMAPE: 12.8747	valid_1's l2: 47.8722	valid_1's SMAPE: 13.4944
# [4800]	training's l2: 51.5225	training's SMAPE: 12.8714	valid_1's l2: 47.8604	valid_1's SMAPE: 13.4928
# [4900]	training's l2: 51.483	training's SMAPE: 12.8682	valid_1's l2: 47.8519	valid_1's SMAPE: 13.4914
# [5000]	training's l2: 51.4441	training's SMAPE: 12.865	valid_1's l2: 47.8427	valid_1's SMAPE: 13.4899
# [5100]	training's l2: 51.4074	training's SMAPE: 12.8621	valid_1's l2: 47.8319	valid_1's SMAPE: 13.4889
# [5200]	training's l2: 51.3714	training's SMAPE: 12.859	valid_1's l2: 47.8049	valid_1's SMAPE: 13.4859
# [5300]	training's l2: 51.3362	training's SMAPE: 12.8561	valid_1's l2: 47.7937	valid_1's SMAPE: 13.4851
# [5400]	training's l2: 51.3011	training's SMAPE: 12.8531	valid_1's l2: 47.7864	valid_1's SMAPE: 13.484
# [5500]	training's l2: 51.2669	training's SMAPE: 12.8505	valid_1's l2: 47.7757	valid_1's SMAPE: 13.4827
# [5600]	training's l2: 51.2334	training's SMAPE: 12.8477	valid_1's l2: 47.7645	valid_1's SMAPE: 13.4812
# [5700]	training's l2: 51.1998	training's SMAPE: 12.8451	valid_1's l2: 47.762	valid_1's SMAPE: 13.4801
# [5800]	training's l2: 51.1666	training's SMAPE: 12.8424	valid_1's l2: 47.7532	valid_1's SMAPE: 13.4792
# [5900]	training's l2: 51.1335	training's SMAPE: 12.8398	valid_1's l2: 47.744	valid_1's SMAPE: 13.4782
# [6000]	training's l2: 51.1017	training's SMAPE: 12.8375	valid_1's l2: 47.7415	valid_1's SMAPE: 13.4775
# [6100]	training's l2: 51.0704	training's SMAPE: 12.8351	valid_1's l2: 47.7356	valid_1's SMAPE: 13.4766
# [6200]	training's l2: 51.0393	training's SMAPE: 12.8326	valid_1's l2: 47.7263	valid_1's SMAPE: 13.4759
# [6300]	training's l2: 51.0096	training's SMAPE: 12.8304	valid_1's l2: 47.7232	valid_1's SMAPE: 13.4752
# [6400]	training's l2: 50.9788	training's SMAPE: 12.8281	valid_1's l2: 47.7223	valid_1's SMAPE: 13.4748
# [6500]	training's l2: 50.9484	training's SMAPE: 12.8258	valid_1's l2: 47.7162	valid_1's SMAPE: 13.4742
# [6600]	training's l2: 50.9192	training's SMAPE: 12.8237	valid_1's l2: 47.7098	valid_1's SMAPE: 13.4732
# [6700]	training's l2: 50.8896	training's SMAPE: 12.8213	valid_1's l2: 47.7049	valid_1's SMAPE: 13.4723
# [6800]	training's l2: 50.8605	training's SMAPE: 12.8192	valid_1's l2: 47.6993	valid_1's SMAPE: 13.4718
# [6900]	training's l2: 50.8322	training's SMAPE: 12.817	valid_1's l2: 47.6959	valid_1's SMAPE: 13.4712
# [7000]	training's l2: 50.8033	training's SMAPE: 12.8148	valid_1's l2: 47.6849	valid_1's SMAPE: 13.4702
# [7100]	training's l2: 50.7749	training's SMAPE: 12.8128	valid_1's l2: 47.6827	valid_1's SMAPE: 13.4699
# [7200]	training's l2: 50.7468	training's SMAPE: 12.8107	valid_1's l2: 47.6792	valid_1's SMAPE: 13.4696
# [7300]	training's l2: 50.7188	training's SMAPE: 12.8087	valid_1's l2: 47.6723	valid_1's SMAPE: 13.4687
# [7400]	training's l2: 50.6914	training's SMAPE: 12.8066	valid_1's l2: 47.6723	valid_1's SMAPE: 13.4683
# [7500]	training's l2: 50.6636	training's SMAPE: 12.8047	valid_1's l2: 47.6667	valid_1's SMAPE: 13.4675
# [7600]	training's l2: 50.6371	training's SMAPE: 12.8027	valid_1's l2: 47.6634	valid_1's SMAPE: 13.4674
# [7700]	training's l2: 50.61	training's SMAPE: 12.8006	valid_1's l2: 47.6633	valid_1's SMAPE: 13.4669
# [7800]	training's l2: 50.5834	training's SMAPE: 12.7987	valid_1's l2: 47.6635	valid_1's SMAPE: 13.4664
# [7900]	training's l2: 50.5578	training's SMAPE: 12.7968	valid_1's l2: 47.6632	valid_1's SMAPE: 13.4661
# [8000]	training's l2: 50.5319	training's SMAPE: 12.7948	valid_1's l2: 47.6554	valid_1's SMAPE: 13.4652
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8100]	training's l2: 50.5059	training's SMAPE: 12.7931	valid_1's l2: 47.6556	valid_1's SMAPE: 13.4651
# Early stopping, best iteration is:
# [7988]	training's l2: 50.5349	training's SMAPE: 12.7951	valid_1's l2: 47.6546	valid_1's SMAPE: 13.465

# %%
y_pred_val = model.predict(X_val, num_iteration=model.best_iteration)

# %%
smape(y_pred_val, Y_val)
# Out:
# 13.464997820641972

# %%
def plot_lgb_importances(model, plot=False, num=10):
    gain = model.feature_importance('gain')
    feat_imp = pd.DataFrame({'feature': model.feature_name(),
                             'split': model.feature_importance('split'),
                             'gain': 100 * gain / gain.sum()}).sort_values('gain', ascending=False)
    if plot:
        plt.figure(figsize=(10, 10))
        sns.set(font_scale=1)
        sns.barplot(x="gain", y="feature", data=feat_imp[0:25])
        plt.title('feature')
        plt.tight_layout()
        plt.show(block=True)
    else:
        print(feat_imp.head(num))
    return feat_imp

# %%
plot_lgb_importances(model, num=30, plot=True)
# Out:
#                  feature  split       gain
# 8            sales_lag_7   6719  42.826653
# 16    sales_roll_mean_30   4459  23.369469
# 9           sales_lag_14   5608  18.865656
# 7            sales_lag_1   5902   8.181778
# 18   sales_roll_mean_546   7601   1.057300
# ..                   ...    ...        ...
# 61                item_3      1   0.000004
# 88               item_30      1   0.000003
# 90               item_32      0   0.000000
# 100              item_42      0   0.000000
# 84               item_26      0   0.000000
#
# [128 rows x 3 columns]

# %%
feat_imp = plot_lgb_importances(model, num=200)

low_importance = feat_imp[feat_imp["gain"] <= 0.005]["feature"].values

dff = df.drop(low_importance, axis=1)

cols_dff = [col for col in dff.columns if col not in ['date', 'id', "sales", "year"]]
# Out:
#                  feature  split       gain
# 8            sales_lag_7   6719  42.826653
# 16    sales_roll_mean_30   4459  23.369469
# 9           sales_lag_14   5608  18.865656
# 7            sales_lag_1   5902   8.181778
# 18   sales_roll_mean_546   7601   1.057300
# ..                   ...    ...        ...
# 61                item_3      1   0.000004
# 88               item_30      1   0.000003
# 90               item_32      0   0.000000
# 100              item_42      0   0.000000
# 84               item_26      0   0.000000
#
# [128 rows x 3 columns]

# %% [markdown]
# Final Model

# %%
train = dff.loc[~df.sales.isna()]
Y_train = train['sales']
X_train = train[cols_dff]


test = dff.loc[df.sales.isna()]
X_test = test[cols_dff]

# %%
lgb_params = {'num_leaves': 10,
              'learning_rate': 0.02,
              'feature_fraction': 0.8,
              'max_depth': 5,
              'verbose': 0,
              'nthread': -1,
              "num_boost_round": model.best_iteration}

# %%
lgbtrain_all = lgb.Dataset(data=X_train, label=Y_train, feature_name=cols_dff)

# %%
final_model = lgb.train(lgb_params, lgbtrain_all, num_boost_round=model.best_iteration)
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
test_preds = final_model.predict(X_test, num_iteration=model.best_iteration)

# %%
train_len = len(Y_train)
test_len = len(test_preds)
all_len = train_len + test_len
xticks_step = 200000

plt.plot(np.arange(train_len), Y_train, label="historical data")
plt.plot(np.arange(train_len, all_len), test_preds, label="forecasted data")
plt.legend()
plt.xticks(np.arange(0, all_len, xticks_step), df['date'].sort_values()[::xticks_step], rotation=70);
